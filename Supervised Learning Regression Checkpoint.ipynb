# %% [markdown]
# ### GOMYCODE MACHINE LEARNING PROJECT
# IntroductionIn this checkpoint, you are going to work on the '5G-Energy consumption' dataset that was provided by the international telecommunication union (ITU) in 2023 as part of a global challenge or competition for data scientists all over the world to solve the 5G energy consumption modelling using machine learning techniques.e)
#
# The columns in the dataset incluTimeNBSSEnergy loadpESMODEaTXpoweru
# iz Summary: Supervised Learning Regression Checkpoint Note: This the link to the Dataset https://drive.google.com/file/d/1vW9TA7KAn-OJjD_o9Rd0l6sx77wNaiuk/view?usp=sharingrform very we

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:/Users/user/Desktop/Gomycode/Checkpoints/5G_energy_consumption_dataset.csv')

# %%
df.head()
# Out:
#               Time   BS     Energy      load  ESMODE   TXpower
# 0  20230101 010000  B_0  64.275037  0.487936     0.0  7.101719
# 1  20230101 020000  B_0  55.904335  0.344468     0.0  7.101719
# 2  20230101 030000  B_0  57.698057  0.193766     0.0  7.101719
# 3  20230101 040000  B_0  55.156951  0.222383     0.0  7.101719
# 4  20230101 050000  B_0  56.053812  0.175436     0.0  7.101719

# %%
df
# Out:
#                   Time      BS     Energy      load  ESMODE   TXpower
# 0      20230101 010000     B_0  64.275037  0.487936     0.0  7.101719
# 1      20230101 020000     B_0  55.904335  0.344468     0.0  7.101719
# 2      20230101 030000     B_0  57.698057  0.193766     0.0  7.101719
# 3      20230101 040000     B_0  55.156951  0.222383     0.0  7.101719
# 4      20230101 050000     B_0  56.053812  0.175436     0.0  7.101719
# ...                ...     ...        ...       ...     ...       ...
# 92624  20230102 170000  B_1018  14.648729  0.087538     0.0  7.325859
# 92625  20230102 180000  B_1018  14.648729  0.082635     0.0  7.325859
# 92626  20230102 210000  B_1018  13.452915  0.055538     0.0  7.325859
# 92627  20230102 220000  B_1018  13.602392  0.058077     0.0  7.325859
# 92628  20230102 230000  B_1018  13.303438  0.048173     0.0  7.325859
#
# [92629 rows x 6 columns]

# %%
df.describe()
# Out:
#              Energy          load        ESMODE       TXpower
# count  92629.000000  92629.000000  92629.000000  92629.000000
# mean      28.138997      0.244705      0.081361      6.765427
# std       13.934645      0.234677      0.382317      0.309929
# min        0.747384      0.000000      0.000000      5.381166
# 25%       18.236173      0.057370      0.000000      6.427504
# 50%       24.065770      0.165550      0.000000      6.875934
# 75%       35.724963      0.363766      0.000000      6.875934
# max      100.000000      0.993957      4.000000      8.375336

# %%
df.shape
# Out:
# (92629, 6)

# %% [markdown]
# ### Display general information about the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92629 entries, 0 to 92628
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Time     92629 non-null  object
#  1   BS       92629 non-null  object
#  2   Energy   92629 non-null  float64
#  3   load     92629 non-null  float64
#  4   ESMODE   92629 non-null  float64
#  5   TXpower  92629 non-null  float64
# dtypes: float64(4), object(2)
# memory usage: 4.2+ MB

# %% [markdown]
# ### Create a pandas profiling reports to gain insights into the dataset

# %%
Sample_5G = df.sample(1000)

# %%
Sample_5G
# Out:
#                   Time     BS     Energy      load    ESMODE   TXpower
# 21325  20230104 200000  B_193  24.813154  0.256520  0.000000  6.875934
# 54112  20230106 170000  B_492  28.251121  0.126273  0.000000  6.875934
# 61567  20230104 180000  B_559  33.183856  0.701240  0.000000  6.875934
# 46919  20230105 030000  B_427  16.292975  0.009130  0.000000  6.875934
# 78403  20230103 000000  B_711  20.627803  0.164280  0.000000  6.875934
# ...                ...    ...        ...       ...       ...       ...
# 35429  20230101 150000  B_323  37.070254  0.613440  0.000000  6.875934
# 76350  20230103 160000  B_692  49.177877  0.247702  0.000000  7.100897
# 78194  20230103 160000  B_709  48.729447  0.318436  0.000000  7.100897
# 9298   20230101 020000   B_85  16.741405  0.020000  0.000000  6.594544
# 26703  20230106 070000  B_242  22.720478  0.167060  0.000833  6.576981
#
# [1000 rows x 6 columns]

# %%
from ydata_profiling import ProfileReport

# %%
report =  ProfileReport(Sample_5G)

# %%
report
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v0.0.dev0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-06-11 09:14:24.273280&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# ### Handle Missing and corrupted values

# %%
df.isnull().sum()
# Out:
# Time       0
# BS         0
# Energy     0
# load       0
# ESMODE     0
# TXpower    0
# dtype: int64

# %% [markdown]
# ### Remove duplicate, if they exist

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 92624    False
# 92625    False
# 92626    False
# 92627    False
# 92628    False
# Length: 92629, dtype: bool

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Time, BS, Energy, load, ESMODE, TXpower]
# Index: []

# %%
df
# Out:
#                   Time      BS     Energy      load  ESMODE   TXpower
# 0      20230101 010000     B_0  64.275037  0.487936     0.0  7.101719
# 1      20230101 020000     B_0  55.904335  0.344468     0.0  7.101719
# 2      20230101 030000     B_0  57.698057  0.193766     0.0  7.101719
# 3      20230101 040000     B_0  55.156951  0.222383     0.0  7.101719
# 4      20230101 050000     B_0  56.053812  0.175436     0.0  7.101719
# ...                ...     ...        ...       ...     ...       ...
# 92624  20230102 170000  B_1018  14.648729  0.087538     0.0  7.325859
# 92625  20230102 180000  B_1018  14.648729  0.082635     0.0  7.325859
# 92626  20230102 210000  B_1018  13.452915  0.055538     0.0  7.325859
# 92627  20230102 220000  B_1018  13.602392  0.058077     0.0  7.325859
# 92628  20230102 230000  B_1018  13.303438  0.048173     0.0  7.325859
#
# [92629 rows x 6 columns]

# %%
df.shape
# Out:
# (92629, 6)

# %% [markdown]
# ### Handle outliers, if they exsit

# %%
df.describe()
# Out:
#              Energy          load        ESMODE       TXpower
# count  92629.000000  92629.000000  92629.000000  92629.000000
# mean      28.138997      0.244705      0.081361      6.765427
# std       13.934645      0.234677      0.382317      0.309929
# min        0.747384      0.000000      0.000000      5.381166
# 25%       18.236173      0.057370      0.000000      6.427504
# 50%       24.065770      0.165550      0.000000      6.875934
# 75%       35.724963      0.363766      0.000000      6.875934
# max      100.000000      0.993957      4.000000      8.375336

# %%
Q1 = df.Energy.quantile(0.25)
Q3 = df.Energy.quantile(0.75)
Q1, Q3
# Out:
# (18.23617339, 35.72496263)

# %%
IQR = Q3 - Q1
IQR
# Out:
# 17.48878924

# %%
lower_limit = Q1 - 1.5*IQR
upper_limit = Q3 + 1.5*IQR
lower_limit, upper_limit
# Out:
# (-7.997010469999996, 61.95814649)

# %%
df[(df.Energy < lower_limit) | (df.Energy > upper_limit)] # THIS IS TO BRING OUT THE OUTLIERS.
# Out:
#                   Time     BS     Energy      load  ESMODE   TXpower
# 0      20230101 010000    B_0  64.275037  0.487936     0.0  7.101719
# 5      20230101 070000    B_0  82.959641  0.351585     0.0  7.101719
# 6      20230101 080000    B_0  91.031390  0.759298     0.0  7.101719
# 7      20230101 090000    B_0  78.176383  0.887798     0.0  7.101719
# 8      20230101 100000    B_0  72.645740  0.624745     0.0  7.101719
# ...                ...    ...        ...       ...     ...       ...
# 92205  20230102 130000  B_983  64.573991  0.452729     0.0  8.375336
# 92206  20230102 150000  B_983  74.588939  0.573759     0.0  8.375336
# 92208  20230102 170000  B_983  64.275037  0.465338     0.0  8.375336
# 92209  20230102 180000  B_983  82.212257  0.634722     0.0  8.375336
# 92210  20230102 190000  B_983  67.563528  0.483068     0.0  8.375336
#
# [2192 rows x 6 columns]

# %%
df_no_outlier = df[(df.Energy > lower_limit) & (df.Energy < upper_limit)]

# %%
df_no_outlier
# Out:
#                   Time      BS     Energy      load  ESMODE   TXpower
# 1      20230101 020000     B_0  55.904335  0.344468     0.0  7.101719
# 2      20230101 030000     B_0  57.698057  0.193766     0.0  7.101719
# 3      20230101 040000     B_0  55.156951  0.222383     0.0  7.101719
# 4      20230101 050000     B_0  56.053812  0.175436     0.0  7.101719
# 20     20230102 020000     B_0  55.754858  0.210952     0.0  7.101719
# ...                ...     ...        ...       ...     ...       ...
# 92624  20230102 170000  B_1018  14.648729  0.087538     0.0  7.325859
# 92625  20230102 180000  B_1018  14.648729  0.082635     0.0  7.325859
# 92626  20230102 210000  B_1018  13.452915  0.055538     0.0  7.325859
# 92627  20230102 220000  B_1018  13.602392  0.058077     0.0  7.325859
# 92628  20230102 230000  B_1018  13.303438  0.048173     0.0  7.325859
#
# [90437 rows x 6 columns]

# %% [markdown]
# #### Select your target variable and the features

# %%
df = df.drop(columns=["BS"], axis=True)

# %%
df
# Out:
#                   Time     Energy      load  ESMODE   TXpower
# 0      20230101 010000  64.275037  0.487936     0.0  7.101719
# 1      20230101 020000  55.904335  0.344468     0.0  7.101719
# 2      20230101 030000  57.698057  0.193766     0.0  7.101719
# 3      20230101 040000  55.156951  0.222383     0.0  7.101719
# 4      20230101 050000  56.053812  0.175436     0.0  7.101719
# ...                ...        ...       ...     ...       ...
# 92624  20230102 170000  14.648729  0.087538     0.0  7.325859
# 92625  20230102 180000  14.648729  0.082635     0.0  7.325859
# 92626  20230102 210000  13.452915  0.055538     0.0  7.325859
# 92627  20230102 220000  13.602392  0.058077     0.0  7.325859
# 92628  20230102 230000  13.303438  0.048173     0.0  7.325859
#
# [92629 rows x 5 columns]

# %%
X = df.drop(columns=["Energy"], axis=True)

# %%
X
# Out:
#                   Time      load  ESMODE   TXpower
# 0      20230101 010000  0.487936     0.0  7.101719
# 1      20230101 020000  0.344468     0.0  7.101719
# 2      20230101 030000  0.193766     0.0  7.101719
# 3      20230101 040000  0.222383     0.0  7.101719
# 4      20230101 050000  0.175436     0.0  7.101719
# ...                ...       ...     ...       ...
# 92624  20230102 170000  0.087538     0.0  7.325859
# 92625  20230102 180000  0.082635     0.0  7.325859
# 92626  20230102 210000  0.055538     0.0  7.325859
# 92627  20230102 220000  0.058077     0.0  7.325859
# 92628  20230102 230000  0.048173     0.0  7.325859
#
# [92629 rows x 4 columns]

# %%
Y = df.Energy

# %%
Y
# Out:
# 0        64.275037
# 1        55.904335
# 2        57.698057
# 3        55.156951
# 4        56.053812
#            ...
# 92624    14.648729
# 92625    14.648729
# 92626    13.452915
# 92627    13.602392
# 92628    13.303438
# Name: Energy, Length: 92629, dtype: float64

# %% [markdown]
# ### Split your dataset to training and test sets

# %%
from sklearn.model_selection import train_test_split

# %%
df = df.drop(columns=["Time"], axis=True)

# %%
df
# Out:
#           Energy      load  ESMODE   TXpower
# 0      64.275037  0.487936     0.0  7.101719
# 1      55.904335  0.344468     0.0  7.101719
# 2      57.698057  0.193766     0.0  7.101719
# 3      55.156951  0.222383     0.0  7.101719
# 4      56.053812  0.175436     0.0  7.101719
# ...          ...       ...     ...       ...
# 92624  14.648729  0.087538     0.0  7.325859
# 92625  14.648729  0.082635     0.0  7.325859
# 92626  13.452915  0.055538     0.0  7.325859
# 92627  13.602392  0.058077     0.0  7.325859
# 92628  13.303438  0.048173     0.0  7.325859
#
# [92629 rows x 4 columns]

# %%
X_train, x_test, Y_train, y_test = train_test_split(df[["load", "ESMODE", "TXpower"]], df.Energy, test_size=0.20)

# %%
X_train
# Out:
#            load    ESMODE   TXpower
# 56611  0.110180  0.000000  6.427504
# 49679  0.539230  0.000000  6.875934
# 66310  0.471600  0.000000  6.427504
# 28545  0.050260  0.000000  6.875934
# 43195  0.486394  0.000000  6.875934
# ...         ...       ...       ...
# 16104  0.372940  0.000000  6.875934
# 2130   0.060940  0.002222  6.875934
# 7251   0.082152  0.000000  6.427504
# 52842  0.013280  0.000000  6.875934
# 82467  0.139080  0.000000  6.875934
#
# [74103 rows x 3 columns]

# %%
Y_train
# Out:
# 56611    19.880419
# 49679    18.086697
# 66310    24.364723
# 28545    23.019432
# 43195    40.508221
#            ...
# 16104    27.503737
# 2130     18.983558
# 7251     29.147982
# 52842    22.869955
# 82467    24.962631
# Name: Energy, Length: 74103, dtype: float64

# %%
x_test.shape
# Out:
# (18526, 3)

# %%
y_test
# Out:
# 1740     31.838565
# 52654    24.364723
# 83716    16.442451
# 34735    43.946188
# 23067    51.868460
#            ...
# 69348    42.750374
# 77179    53.811659
# 5082     53.363229
# 66388    25.261584
# 66002    35.575486
# Name: Energy, Length: 18526, dtype: float64

# %%
X_train.shape
# Out:
# (74103, 3)

# %%
y_test.shape
# Out:
# (18526,)

# %% [markdown]
# ### Based on your data exploration phase select a ML regression algorithm and train it on the training set

# %%
from sklearn import linear_model

# %%
reg = linear_model.LinearRegression()
reg.fit(df[["load", "ESMODE", "TXpower"]], df["Energy"])
# Out:
# LinearRegression()

# %% [markdown]
# ### Assess your model performance on the test set using relevant evaluation metrics

# %%
reg.score(x_test,y_test)
# Out:
# 0.5601007710032935

# %% [markdown]
# ### Discuss with your cohort alternative ways to improve your model performance
